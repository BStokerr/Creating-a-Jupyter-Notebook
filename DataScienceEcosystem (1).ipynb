# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarised

# %% [markdown]
# **Objectives:**
# - List some of the Popular languages used by Data Scientists
# - List some of the libraries commonly used by Data Scientists
# - Write Python code that executes some basic arithmetic

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Scala

# %% [markdown]
# Some of the commonly used libraries used bu Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. MatPlotLib

# %% [markdown]
# |Data Science Tools |
# | ----------------- |
# | RStudio |
# | Anaconda |
# | Apache Hadoop |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression that multiplies then adds integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Benjamin Stoker
